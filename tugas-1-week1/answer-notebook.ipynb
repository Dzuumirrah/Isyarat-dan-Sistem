# %% [markdown]
# # A. Tugas analitik

# %% [markdown]
# <img src="analitis.png" min-width=700px max-width=1000px>

# %% [markdown]
# ## 1. Grafik fungsi sinus dengan $f = 5Hz$ dan $\theta = \frac{\pi}{2}$

# %% [markdown]
#
# Rumus sinyal sinus secara umum
#
# ```math
# f(t) = A\sin(ωt-φ)
# ```
# dengan
#
# ```math
# A=\text{amplitudo } (m), \\
# ω=\text{kecepatan sudut } (\frac{rad}{s})=2πf=\frac{2π}{T}, \\
# t=\text{waktu } (s)
# ```
#
# Jika sebuah sinyal memiliki frekuensi 5 Hz, sinyal tersebut akan melakukan 5 kali putaran dalam satu detik (dalam satu putaran terdapat 1 lembah dan satu puncak) sehingga terdapat 5 lembah dan 5 puncak tiap satu detik. <br>
# Jika sebuah sinyal memiliki fase awal sebesar θ=π/2 radiant, grafik sinyal tersebut akan dimulai dari sudut π/2  radiant atau jika dikonversi ke sudut 360°, maka grafik akan dimulai dari sudut 90°. Visualisasi dari grafik tersebut dapat ditampilkan sebagai berikut.<br>

# %%
# import library yang dibutuhkan
import numpy as np
import matplotlib.pyplot as plt

# %%
# Pembuatan grafik
# Shortcut
sin = np.sin
pi = np.pi

# deklarasi nilai setiap variabel
A = 1               # Amplitudo
f = 5               # Frekuensi (Hz)
theta = pi/2     # Fase awal

# Setting plot untuk grafik
t = np.linspace(0, 2, 1000)
x_t = A * sin(2*pi*f*t - theta)

plt.figure(figsize=(10,2))      # size dalam inci
plt.plot(t, x_t)
plt.title("Grafik fungsi sinusoidal 5Hz dengan Fase awal pi/2")
plt.xlabel("waktu (s)")
plt.show()

# %% [markdown]
# ## 2. Grafik fungsi sinus dengan $f = 10Hz, 20Hz, 30Hz$ dan $\theta = 0$

# %%
# pembuatan grafik
# deklarasi nilai setiap variabel
A = 1
f_1 = 10
f_2 = 20
f_3 = 30
theta = 0

# Setting plot untuk grafik
t = np.linspace(0, 1, 1000)                         # t = 1 detik

# Fungsi yang dipakai
x_t_1 = A * sin(2*pi*f_1*t - theta)
x_t_2 = A * sin(2*pi*f_2*t - theta)
x_t_3 = A * sin(2*pi*f_3*t - theta)

# Konfigurasi subplot
fig, axs = plt.subplots(2, 2, figsize=(20, 7))

# Grafik 10Hz
axs[0][0].plot(t, x_t_1, color="green")
axs[0][0].set_title("f = 10Hz")
axs[0][0].set_xlabel("Waktu (s)")
axs[0][0].set_ylabel("Amplitudo")

# Grafik 20Hz
axs[0][1].plot(t, x_t_2, color="blue")
axs[0][1].set_title("f = 20Hz")
axs[0][1].set_xlabel("Waktu (s)")
axs[0][1].set_ylabel("Amplitudo")

# Grafik 30Hz
axs[1][0].plot(t, x_t_3, color="red")
axs[1][0].set_title("f = 30Hz")
axs[1][0].set_xlabel("Waktu (s)")
axs[1][0].set_ylabel("Amplitudo")


plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Analisis persamaan berdasarkan ilustrasi grafik

# %% [markdown]
# ### a. Grafik kiri
# ![image.png](attachment:image.png)

# %% [markdown]
# Ilustrasi tersebut berisi grafik dengan fungsi step. Terdapat tiga fase dari grafik tersebut.<br>
# 1. Fase saat y = 0,
# 2. Fase saat y = 1, dan
# 3. Fase saat y = 2
#
# Dengan demikian, fungsi dari grafik tersebut adalah:
# ```math
# f(x)= \left\{
# \begin{aligned}
#     & 0;                &\quad x  < -2 \text{ atau } x >2 \\
#     & 1;                &\quad -2 \leq x < -1 \text{ atau } 1 \leq x < 2\\
#     & 2;                &\quad -1 \leq x < 1
# \end{aligned}
# \right.
# ```

# %% [markdown]
# ### b. Grafik kanan
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Ilustrasi tersebut berisi grafik dengan fungsi ramp dan fungsi step. Terdapat tiga fase dari grafik tersebut.<br>
# 1. Fase saat grafik menaik dari y = 0 hingga y = 1,
# 2. Fase saat y = 1, dan
# 3. Fase saat grafik menurun dari y = 1 hingga y = 0
#
# Dengan demikian, fungsi dari grafik tersebut adalah:
# ```math
# f(x)= \left\{
# \begin{aligned}
#     &\frac{1}{4}x;         &\quad -4 \leq x < -1 \\
#     &1;                    &\quad -1 \leq x < 1 \\
#     &-\frac{1}{4}x;         &\quad 1 \leq x < 4
# \end{aligned}
# \right.
# ```

# %% [markdown]
# # B. Matlab
# <img src="matlab.png" min-width=700px max-width=1000px>

# %% [markdown]
# ## 1. Bangkitkan sinyal sesuai nomor A.1

# %%
# Import library yang dibutuhkan
import numpy as np
import matplotlib.pyplot as plt

# %%
# Pembuatan grafik
# Shortcut
sin = np.sin
pi = np.pi

# deklarasi nilai setiap variabel
A = 1               # Amplitudo
f = 5               # Frekuensi (Hz)
theta = pi/2     # Fase awal

# Setting plot untuk grafik
t = np.linspace(0, 2, 1000)
x_t = A * sin(2*pi*f*t - theta)

plt.figure(figsize=(15, 2))      # size dalam inci
plt.plot(t, x_t)
plt.title("Grafik fungsi sinusoidal 5Hz dengan Fase awal pi/2")
plt.xlabel("waktu (s)")
plt.show()

# %% [markdown]
# ## 2. Bangkitkan dan tampilkan grafik dua buah sinyal sinus dengan fungsi tertentu, lalu **jumlahkan** kedua sinyal tersebut dan tampilkan grafiknya

# %% [markdown]
# fungsi:
# 1. $ S_1(t) = \sin (8\pi f_c t) $
# 2. $ S_2(t) = \sin (5\pi f_c t + 0.5\pi) $
#
# Karena di dalam soal tidak disebutkan nilai $f_c$, maka penulis mengasumsikan nilai $f_c = 5Hz$

# %%
# Pembuatan grafik tiap fungsi
# Shortcut 
sin = np.sin
pi = np.pi

# Deklarasi variabel
f_c = 5                         # satuan Hz
t = np.linspace(0, 2, 1000)     # Range dari 0 - 2 sec.  

# Deklarasi fungsi
s_t1 = sin(8 * pi * f_c * t)
s_t2 = sin(5 * pi * f_c * t + 0.5*pi)
s_sum = s_t1 + s_t2

# Konfigurasi sub plot
fig, axs = plt.subplots(3, 1, figsize=(15,10))


# Grafik s_1(t)
axs[0].set_ylim(-2,2)
axs[0].set_title("Grafik Fungsi S_1(t)")
axs[0].set_xlabel("waktu (s)")
axs[0].set_ylabel("Amplitudo")
axs[0].plot(t, s_t1, color="green")
axs[0].grid(True)

# Grafik s_1(t)
axs[1].set_ylim(-2,2)
axs[1].set_title("Grafik Fungsi S_2(t)")
axs[1].set_xlabel("waktu (s)")
axs[1].set_ylabel("Amplitudo")
axs[1].plot(t, s_t2, color="blue")
axs[1].grid(True)

# Grafik penjumlahan kedua fungsi sebelumnya
axs[2].set_ylim(-2,2)
axs[2].set_title("Grafik Fungsi s_product(t)")
axs[2].set_xlabel("waktu (s)")
axs[2].set_ylabel("Amplitudo")
axs[2].plot(t, s_product, color="red")
axs[2].grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Bangkitkan dan tampilkan grafik dua buah sinyal sinus dengan fungsi tertentu, lalu **kalikan** kedua sinyal tersebut dan tampilkan grafiknya

# %% [markdown]
# fungsi:
# 1. $ S_1(t) = \sin (2\pi f_s t) $
# 2. $ S_2(t) = \sin (5\pi f_c t) $
#
# Karena di dalam soal tidak disebutkan nilai $f_c$ dan $f_s$, maka penulis mengasumsikan nilai $f_c = 10Hz$ dan $f_s = 2Hz$

# %%
# Pembuatan grafik tiap fungsi
# Deklarasi variabel
f_c = 10                         # satuan Hz
f_s = 2
t = np.linspace(0, 2, 1000)     # Range dari 0 - 2 sec.  

# Deklarasi fungsi
s_t1 = sin(2 * pi * f_c * t)
s_t2 = sin(5 * pi * f_s * t)
s_product = s_t1 * s_t2

# Konfigurasi sub plot
fig, axs = plt.subplots(3, 1, figsize=(15,10))


# Grafik s_1(t)
axs[0].set_ylim(-2,2)
axs[0].set_title("Grafik Fungsi S_1(t)")
axs[0].set_xlabel("waktu (s)")
axs[0].set_ylabel("Amplitudo")
axs[0].plot(t, s_t1, color="green")
axs[0].grid(True)

# Grafik s_1(t)
axs[1].set_ylim(-2,2)
axs[1].set_title("Grafik Fungsi S_2(t)")
axs[1].set_xlabel("waktu (s)")
axs[1].set_ylabel("Amplitudo")
axs[1].plot(t, s_t2, color="blue")
axs[1].grid(True)

# Grafik penjumlahan kedua fungsi sebelumnya
axs[2].set_ylim(-2,2)
axs[2].set_title("Grafik Fungsi S_product(t)")
axs[2].set_xlabel("waktu (s)")
axs[2].set_ylabel("Amplitudo")
axs[2].plot(t, s_product, color="red")
axs[2].grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Bangkitkan sebuah sinyal dan lemahkan sinyal tersebut sebesar $x\%$

# %% [markdown]
# fungsi: <br>
# $s(t) = \sin (5\pi f_c t)$
#
# $f_c = 10Hz$

# %%
# Pembuatan grafik
# Deklarasi variabel
f_c = 10                        # Satuan Hz
t = np.linspace(0, 2, 1000)
pelemahan = 1-0.2              # Dilemahkan sebesar 20%

# Deklarasi fungsi
s_t = sin(5 * pi * f_c * t)
s_t_lemah = s_t*pelemahan

# Konfigurasi subplot
fig, axs = plt.subplots(2, 1, figsize=(15, 7))

# Grafik sebelum pelemahan
axs[0].set_ylim(-1,1)
axs[0].set_xlim(0, 1)
axs[0].grid(True)
axs[0].set_title("Grafik s_t")
axs[0].set_xlabel("waktu (s)")
axs[0].set_ylabel("Amplitudo")
axs[0].plot(t, s_t, color="red")

# Grafik setelah pelemahan
axs[1].set_ylim(-1,1)
axs[1].set_xlim(0, 1)
axs[1].grid(True)
axs[1].set_title("Grafik s_t setelah pelemahan")
axs[1].set_xlabel("waktu (s)")
axs[1].set_ylabel("Amplitudo")
axs[1].plot(t, s_t_lemah, color="green")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Bangkitkan sebuah sinyal dan amplifikasi sinyal tersebut sebesar $x\times$

# %% [markdown]
# Fungsi: <br>
# $s(t) = \sin(5\pi f_c t)$ <br>
# $f_c = 10Hz$<br>
# $amplifikasi = 2.5\times$

# %%
# Pembuatan grafik
# Deklarasi variabel
f_c = 10            # Satuan Hz
amplifikasi = 2.5   # Konstanta

# Deklarasi fungsi
s_t = sin(5*pi*f_c*t)
s_t_kuat = s_t*amplifikasi

# Konfigurasi subplot
fig, axs = plt.subplots(2, 1, figsize=(15,7))

# Grafik sebelum amplifikasi
axs[0].set_ylim(-3,3)
axs[0].set_xlim(0,1)
axs[0].grid(True)
axs[0].set_title("Grafik s_t")
axs[0].set_xlabel("Waktu (s)")
axs[0].set_ylabel("Amplitudo")
axs[0].plot(t, s_t, color="blue")

# Grafik setelah amplifikasi
axs[1].set_ylim(-3,3)
axs[1].set_xlim(0,1)
axs[1].grid(True)
axs[1].set_title("Grafik s_t Setelah Amplifikasi")
axs[1].set_xlabel("Waktu (s)")
axs[1].set_ylabel("Amplitudo")
axs[1].plot(t, s_t_kuat, color="red")

plt.tight_layout()
plt.show()
